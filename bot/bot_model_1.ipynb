# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/new-data-m1/data
# /kaggle/input/fortrade-requirements/requirements.txt
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/.gitignore
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/README.md
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/forex_model_training.ipynb
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/Models/ViT_224/checkpoint.data-00000-of-00001
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/Models/ViT_224/checkpoint.index
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/Models/ViT_224/checkpoint
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Bulls.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/TRIX.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Accelerator.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/W_AD.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/WPR.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MFI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/TEMA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ROC.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/FrAMA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorCandlesDaily.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Accelerator.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MarketFacilitationIndex.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Bulls.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Gator.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Alligator.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/slow-stoch.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Volumes.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MarketFacilitationIndex.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Volumes.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Ultimate_Oscillator.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Bears.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DPO.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/PVT.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Ichimoku.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Ichimoku.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/RSI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ATR.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MFI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/TRIX.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Ultimate_Oscillator.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DeMarker.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ZigzagColor.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/BB.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MACD.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CHO.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ADXW.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ROC.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Price_Channel.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/StdDev.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Heiken_Ashi.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorLine.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Envelopes.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/AMA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/AD.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Awesome_Oscillator.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorLine.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorBars.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CCI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/TEMA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ASI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CHO.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Heiken_Ashi.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Force_Index.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Custom Moving Average.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Stochastic.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Momentum.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/StdDev.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Gator_2.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/BB.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ZigZag.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorCandlesDaily.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Awesome_Oscillator.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/RSI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ColorBars.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ATR.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Gator.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Momentum.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CCI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/VIDYA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/BW-ZoneTrade.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/W_AD.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ZigZag.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ParabolicSAR.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Stochastic.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Fractals.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/MACD.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/VROC.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Force_Index.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/RVI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/RVI.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Gator_2.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/OBV.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DPO.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Envelopes.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/VROC.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/special-slow-stochastic.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CHV.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/slow-stoch.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/OBV.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DEMA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ADX.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Price_Channel.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DeMarker.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ASI.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ParabolicSAR.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/WPR.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/OsMA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Custom Moving Average.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/AMA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/DEMA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/VIDYA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/BW-ZoneTrade.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Bears.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ZigzagColor.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ADXW.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/AD.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/OsMA.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Alligator.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/CHV.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Fractals.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/PVT.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/FrAMA.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/ADX.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Canvas/FlameChart.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Canvas/FlameChart.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/ChartPanel/ChartPanel.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/ChartPanel/PanelDialog.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/ChartPanel/ChartPanel.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/SimplePanel/SimplePanel.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/SimplePanel/SimplePanel.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Indicators/Examples/Panels/SimplePanel/PanelDialog.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/errordescription.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Timer.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Pending.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Trade_DEPRECATED.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/TrailingStops.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Price.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Utils.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/SymbolInfo.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/TradeHedge.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/Indicators.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Include/Mql5Book/MoneyManagement.mqh
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Experts/Advisors/EA_istoch_BB_v08.ex5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Code/MQL5_2020_06_15/Experts/Advisors/EA_istoch_BB_v08.mq5
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_GBPUSD.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_USDJPY.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_EURGBP.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_USDCHF.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_GBPJPY.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2020/2020_EURUSD.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2019/2019_GBPUSD.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2019/2019_EURGBP.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2019/2019_USDCHF.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/2019/2019_EURUSD.png
# /kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Exp/
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting tensorflow-addons==0.21.0
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (1.62.2)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.15.0) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons==0.21.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.15.0) (3.1.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.0 MB/s eta 0:00:00:00:0100:01
# Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 30.2 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.1 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.5 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 89.0 MB/s eta 0:00:00:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: wrapt, typeguard, ml-dtypes, keras, tensorflow-addons, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
#   Attempting uninstall: keras
#     Found existing installation: keras 3.3.3
#     Uninstalling keras-3.3.3:
#       Successfully uninstalled keras-3.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.9.1 requires tf-keras~=2.16, which is not installed.
# s3fs 2024.9.0 requires fsspec==2024.9.0.*, but you have fsspec 2024.6.0 which is incompatible.
# tensorflow-decision-forests 1.9.1 requires tensorflow~=2.16.1, but you have tensorflow 2.15.0 which is incompatible.
# tensorflow-serving-api 2.16.1 requires tensorflow<3,>=2.16.1, but you have tensorflow 2.15.0 which is incompatible.
# tensorstore 0.1.69 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# ydata-profiling 4.12.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# ydata-profiling 4.12.0 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-addons-0.21.0 typeguard-2.13.3 wrapt-1.14.1

# %%
import tensorflow as tf
import tensorflow_addons as tfa

print("TensorFlow Version:", tf.__version__)
print("TensorFlow Addons Version:", tfa.__version__)
# Out:
# 2024-12-18 22:14:55.884084: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 22:14:55.884179: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 22:14:55.886139: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow Version: 2.15.0
# TensorFlow Addons Version: 0.21.0
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# !pip install mplfinance
# !pip install Pillow
# !pip install seaborn
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mplfinance) (3.7.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (10.3.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import mplfinance as fplt
import matplotlib
matplotlib.use('agg')
from matplotlib import image
from matplotlib import pyplot
import pandas as pd
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm 
import seaborn as sn
from sklearn.metrics import classification_report,accuracy_score

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

# %%
forex_df_data = pd.read_csv('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Datasets/MarketMovement/EURUSD/Seqs_2000_1_3_0.txt', sep=";")
forex_df_labels = pd.read_csv('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/Datasets/MarketMovement/EURUSD/Labels_2000_1_3_0.txt', sep=";")
forex_df = pd.merge(forex_df_data, forex_df_labels, on='IDTime')
forex_df.rename(columns={'ReadableTime': 'Date'}, inplace=True)
forex_df['Date']= pd.to_datetime(forex_df['Date']) 
forex_df['Open'] = forex_df['Close']
forex_df['Open'] = forex_df['Open'].shift(1)
forex_df.head(5)
# Out:
#       IDTime                Date    High     Low   Close  BarType  HAType  \
# 0  946857600 2000-01-03 00:00:00  1.0190  1.0073  1.0175        1       1
# 1  946872000 2000-01-03 04:00:00  1.0181  1.0154  1.0157        4       1
# 2  946886400 2000-01-03 08:00:00  1.0167  1.0093  1.0115        2       4
# 3  946900800 2000-01-03 12:00:00  1.0118  1.0054  1.0073        2       2
# 4  946915200 2000-01-03 16:00:00  1.0240  1.0070  1.0218        3       1
#
#    BBSignal  BBBreakoutSignal  StochMain  StochSignal  MarketMov  \
# 0         2                 0   84.57584     84.77898          0
# 1         2                 0   84.83516     83.13700          0
# 2         0                 0   78.31094     82.57398          0
# 3         0                 0   62.99484     75.38031          0
# 4         2                 0   69.29825     70.20134          0
#
#    LabelStrategy Class    Open
# 0              0  sell     NaN
# 1              0  sell  1.0175
# 2              0   buy  1.0157
# 3              0   buy  1.0115
# 4              0  stay  1.0073

# %%
forex_ohlc = forex_df[["Date","Open","High","Low","Close","Class"]].copy()
dt_range = pd.date_range(start="2010.01.01", end="2020.01.01", freq='240min')
forex_ohlc = forex_ohlc[forex_ohlc.Date.isin(dt_range)]
forex_ohlc.reset_index(drop=True,inplace=True)
forex_ohlc.head(5)
total_size = forex_ohlc.shape[0]
train_size = int(0.8*total_size)
test_size = total_size - train_size
min_val = forex_ohlc.Low.min()
max_val = forex_ohlc.High.max()
print("Train set size = {0} and Test set size = {1}".format(train_size,test_size))
train_df = forex_ohlc.iloc[:train_size,:]
test_df = forex_ohlc.iloc[train_size:,:]

train_df

print("Training Dataset\n", train_df['Class'].value_counts(dropna=False))
print("Test Dataset\n", test_df['Class'].value_counts(dropna=False))

print(train_df.head(5))
print(train_df.tail(5))
print(test_df.head(5))
print(test_df.tail(5))
print(min_val, max_val)
# Out:
# Train set size = 12433 and Test set size = 3109
# Training Dataset
#  Class
# stay    8871
# sell    1861
# buy     1701
# Name: count, dtype: int64
# Test Dataset
#  Class
# stay    2833
# sell     149
# buy      127
# Name: count, dtype: int64
#                  Date     Open     High      Low    Close Class
# 0 2010-01-04 00:00:00  1.43306  1.43336  1.42569  1.42939   buy
# 1 2010-01-04 04:00:00  1.42939  1.43090  1.42718  1.42949   buy
# 2 2010-01-04 08:00:00  1.42949  1.43994  1.42688  1.43778   buy
# 3 2010-01-04 12:00:00  1.43778  1.44498  1.43768  1.44266  stay
# 4 2010-01-04 16:00:00  1.44266  1.44543  1.44030  1.44120  stay
#                      Date     Open     High      Low    Close Class
# 12428 2017-12-29 00:00:00  1.19426  1.19492  1.19361  1.19421  stay
# 12429 2017-12-29 04:00:00  1.19421  1.19496  1.19376  1.19491   buy
# 12430 2017-12-29 08:00:00  1.19491  1.19876  1.19460  1.19812  stay
# 12431 2017-12-29 12:00:00  1.19812  1.19986  1.19734  1.19870  stay
# 12432 2017-12-29 16:00:00  1.19870  1.20255  1.19855  1.20215  stay
#                      Date     Open     High      Low    Close Class
# 12433 2017-12-29 20:00:00  1.20215  1.20239  1.19925  1.19957   buy
# 12434 2018-01-02 00:00:00  1.19957  1.20234  1.20011  1.20155  stay
# 12435 2018-01-02 04:00:00  1.20155  1.20246  1.20078  1.20246  stay
# 12436 2018-01-02 08:00:00  1.20246  1.20706  1.20227  1.20704  stay
# 12437 2018-01-02 12:00:00  1.20704  1.20813  1.20562  1.20574  stay
#                      Date     Open     High      Low    Close Class
# 15537 2019-12-31 04:00:00  1.12126  1.12148  1.11988  1.12070  stay
# 15538 2019-12-31 08:00:00  1.12070  1.12175  1.12030  1.12136  stay
# 15539 2019-12-31 12:00:00  1.12136  1.12390  1.12086  1.12380  stay
# 15540 2019-12-31 16:00:00  1.12380  1.12392  1.12162  1.12290  stay
# 15541 2019-12-31 20:00:00  1.12290  1.12290  1.12226  1.12233  stay
# 1.03249 1.49385

# %%
train_df.set_index('Date', inplace=True)
test_df.set_index('Date', inplace=True)

# %%
from random import random, seed
seed(42)
def generate_image(sample_df, save_location_template, fname, sample_stay=False):
  class_name = sample_df.iloc[-1,4] # class of the last operation in the sequence
  roll = 1
  if sample_stay and class_name == 'stay':
    roll = random()
  if roll > 0.8: # only keep 20% of the stay samples because we have so many
    fplt.plot(
        sample_df,
        type='candle',
        style = "yahoo",
      figratio=(1,1),axisoff=True,tight_layout = True,mav=(2,4,6),
        savefig=dict(fname=save_location_template.format(class_name, fname),dpi=100),
        #ylim=(min_val,max_val)
    )

# %%
import glob
from random import shuffle
matplotlib.use('module://ipykernel.pylab.backend_inline')
buy_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Train/buy/*.png')
sell_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Train/sell/*.png')
stay_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Train/stay/*.png')
shuffle(buy_fnames)
shuffle(sell_fnames)
shuffle(stay_fnames)

ROWS = 4
COLS = 4

fig, axes = plt.subplots(ROWS, COLS)
fig.suptitle('BUY')
for r in range(ROWS):
  for c in range(COLS):
    im = plt.imread(buy_fnames[r*ROWS+c])
    axes[r][c].set_axis_off()
    axes[r][c].patch.set_edgecolor('black')  
    axes[r][c].patch.set_linewidth('1')  
    axes[r][c].imshow(im)
    

fig, axes = plt.subplots(ROWS, COLS)
fig.suptitle('STAY')
for r in range(ROWS):
  for c in range(COLS):
    im = plt.imread(stay_fnames[r*ROWS+c])
    axes[r][c].set_axis_off()
    axes[r][c].patch.set_edgecolor('black')  
    axes[r][c].patch.set_linewidth('1')  
    axes[r][c].imshow(im)

fig, axes = plt.subplots(ROWS, COLS)
fig.suptitle('SELL')
for r in range(ROWS):
  for c in range(COLS):
    im = plt.imread(sell_fnames[r*ROWS+c])
    axes[r][c].set_axis_off()
    axes[r][c].patch.set_edgecolor('black')  
    axes[r][c].patch.set_linewidth('1')  
    axes[r][c].imshow(im)

# %%
def mlp(x, hidden_units, dropout_rate):
  for units in hidden_units:
    x = layers.Dense(units, activation=tf.nn.gelu)(x)
    x = layers.Dropout(dropout_rate)(x)
  return x

class Patches(layers.Layer):
  def __init__(self, patch_size):
    super(Patches, self).__init__()
    self.patch_size = patch_size

  def call(self, images):
    batch_size = tf.shape(images)[0]
    patches = tf.image.extract_patches(
      images=images,
      sizes=[1, self.patch_size, self.patch_size, 1],
      strides=[1, self.patch_size, self.patch_size, 1],
      rates=[1, 1, 1, 1],
      padding="VALID",
    )
    patch_dims = patches.shape[-1]
    patches = tf.reshape(patches, [batch_size, -1, patch_dims])
    return patches
  
class PatchEncoder(layers.Layer):
  def __init__(self, num_patches, projection_dim):
    super(PatchEncoder, self).__init__()
    self.num_patches = num_patches
    self.projection = layers.Dense(units=projection_dim)
    self.position_embedding = layers.Embedding(
      input_dim=num_patches, output_dim=projection_dim
    )

  def call(self, patch):
    positions = tf.range(start=0, limit=self.num_patches, delta=1)
    encoded = self.projection(patch) + self.position_embedding(positions)
    return encoded

def create_vit_classifier(input_shape, data_preprocessing):
  inputs = layers.Input(shape=input_shape)
  # Augment data.
  augmented = data_preprocessing(inputs)
  # Create patches.
  patches = Patches(patch_size)(augmented)
  # Encode patches.
  encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

  # Create multiple layers of the Transformer block.
  for _ in range(transformer_layers):
    # Layer normalization 1.
    x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    # Create a multi-head attention layer.
    attention_output = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim, dropout=0.1
    )(x1, x1)
    # Skip connection 1.
    x2 = layers.Add()([attention_output, encoded_patches])
    # Layer normalization 2.
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    # MLP.
    x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
    # Skip connection 2.
    encoded_patches = layers.Add()([x3, x2])

  # Create a [batch_size, projection_dim] tensor.
  representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
  representation = layers.Flatten()(representation)
  representation = layers.Dropout(0.5)(representation)
  # Add MLP.
  features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
  # Classify outputs.
  logits = layers.Dense(3)(features)
  #logits = layers.Dense(1, activation='tanh')(features)
  # Create the Keras model.
  model = keras.Model(inputs=inputs, outputs=logits)
  return model

# %%
## Test patch generation
matplotlib.use('module://ipykernel.pylab.backend_inline')
import matplotlib.pyplot as plt

IMAGE_SIZE=224
PATCH_SIZE=16

plt.figure(figsize=(4, 4))
image = np.asarray(plt.imread('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Train/buy/yahoo_10007.png'))[...,:3]
plt.imshow(image)
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)
patches = Patches(PATCH_SIZE)(resized_image)
print(f"Image size: {IMAGE_SIZE} X {IMAGE_SIZE}")
print(f"Patch size: {PATCH_SIZE} X {PATCH_SIZE}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4), facecolor=(0,0,0))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (PATCH_SIZE, PATCH_SIZE, 3))
    plt.imshow(patch_img.numpy())
    plt.axis("off")
# Out:
# Image size: 224 X 224
# Patch size: 16 X 16
# Patches per image: 196
# Elements per patch: 768

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 64
num_epochs = 65
image_size = 224  # We'll resize input images to this size
patch_size = 16   # Size of the patches to be extracted from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
import glob
from PIL import Image

LBL_MAP = {'buy':0,'sell':1,'stay':2}

train_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Train/*/*.png')
val_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Val/*/*.png')
test_fnames = glob.glob('/kaggle/input/fortrademl/AI_forex_fisichella_garolla_master/content/Test/*/*.png')

x_train = np.asarray([np.asarray(Image.open(fn).convert('RGB').resize((image_size, image_size))) for fn in tqdm(train_fnames)])
y_train = keras.utils.to_categorical(np.asarray([LBL_MAP[fn.split('/')[-2]] for fn in train_fnames]), num_classes=3)

x_val   = np.asarray([np.asarray(Image.open(fn).convert('RGB').resize((image_size, image_size))) for fn in tqdm(val_fnames)])
y_val   = keras.utils.to_categorical(np.asarray([LBL_MAP[fn.split('/')[-2]] for fn in val_fnames]), num_classes=3)

x_test   = np.asarray([np.asarray(Image.open(fn).convert('RGB').resize((image_size, image_size))) for fn in tqdm(test_fnames)])
y_test   = keras.utils.to_categorical(np.asarray([LBL_MAP[fn.split('/')[-2]] for fn in test_fnames]), num_classes=3)


data_preprocessing = keras.Sequential(
    [
        layers.experimental.preprocessing.Normalization()
    ],
    name="data_preprocessing",
)
# Compute the mean and the variance of the training data for normalization.
data_preprocessing.layers[0].adapt(x_train)
# Out:
# 100%|██████████| 4755/4755 [00:48<00:00, 97.16it/s]
# 100%|██████████| 529/529 [00:05<00:00, 98.66it/s]
# 100%|██████████| 3089/3089 [00:31<00:00, 97.69it/s]

# %%
from sklearn.metrics import confusion_matrix

def run_experiment(model, x_train, y_train, x_val, y_val, x_test, y_test, model_name):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
        ],
    )

    checkpoint_filepath = f"/kaggle/working/{model_name}/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    class_weights = {
    0: 3.0,  # 'Stay' (more weight due to low samples)
    1: 3.0,  # 'Buy'
    2: 2.0   # 'Sell' (reduce weight)
    }
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val,y_val),
        validation_batch_size=batch_size,
        callbacks=[checkpoint_callback],
        shuffle=True,
        class_weight=class_weights
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(x_train, y_train)
    print('\nPerformance of best model:')
    print(f"> Train accuracy: {accuracy}")
    _, accuracy = model.evaluate(x_val, y_val)
    print(f"> Val accuracy: {accuracy}")
    _, accuracy = model.evaluate(x_test, y_test)
    print(f"> Test accuracy: {accuracy}")

    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    print('Confusion Matrix:')
    print(cm)

    return history

# %% [markdown]
# # ViT

# %%
vit_classifier = create_vit_classifier((image_size, image_size, 3),data_preprocessing)
history = run_experiment(vit_classifier, x_train, y_train, x_val, y_val, x_test, y_test, 'ViT_224')
# Out:
# Epoch 1/80
# 75/75 [==============================] - 24s 150ms/step - loss: 7.2748 - accuracy: 0.3394 - val_loss: 1.1276 - val_accuracy: 0.3592
# Epoch 2/80
# 75/75 [==============================] - 10s 134ms/step - loss: 3.1381 - accuracy: 0.3546 - val_loss: 1.0977 - val_accuracy: 0.3762
# Epoch 3/80
# 75/75 [==============================] - 8s 111ms/step - loss: 2.9792 - accuracy: 0.3537 - val_loss: 1.0982 - val_accuracy: 0.3686
# Epoch 4/80
# 75/75 [==============================] - 8s 111ms/step - loss: 2.9627 - accuracy: 0.3558 - val_loss: 1.0984 - val_accuracy: 0.3346
# Epoch 5/80
# 75/75 [==============================] - 8s 110ms/step - loss: 2.9263 - accuracy: 0.3508 - val_loss: 1.0936 - val_accuracy: 0.3497
# Epoch 6/80
# 75/75 [==============================] - 10s 130ms/step - loss: 2.9032 - accuracy: 0.3584 - val_loss: 1.0941 - val_accuracy: 0.3856
# Epoch 7/80
# 75/75 [==============================] - 8s 110ms/step - loss: 2.8991 - accuracy: 0.3577 - val_loss: 1.0927 - val_accuracy: 0.3648
# Epoch 8/80
# 75/75 [==============================] - 8s 111ms/step - loss: 2.8773 - accuracy: 0.3794 - val_loss: 1.0929 - val_accuracy: 0.3629
# Epoch 9/80
# 75/75 [==============================] - 8s 111ms/step - loss: 2.8541 - accuracy: 0.3868 - val_loss: 1.0946 - val_accuracy: 0.3667
# Epoch 10/80
# 75/75 [==============================] - 8s 111ms/step - loss: 2.8310 - accuracy: 0.3922 - val_loss: 1.0906 - val_accuracy: 0.3705
80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1290 - accuracy: 0.9828 - val_loss: 2.0633 - val_accuracy: 0.3875
# Epoch 64/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1610 - accuracy: 0.9802 - val_loss: 1.9338 - val_accuracy: 0.3535
# Epoch 65/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1224 - accuracy: 0.9846 - val_loss: 2.0441 - val_accuracy: 0.3592
# Epoch 66/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1226 - accuracy: 0.9857 - val_loss: 2.1958 - val_accuracy: 0.3743
# Epoch 67/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1060 - accuracy: 0.9868 - val_loss: 2.1118 - val_accuracy: 0.3686
# Epoch 68/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1398 - accuracy: 0.9832 - val_loss: 1.7947 - val_accuracy: 0.3554
# Epoch 69/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1023 - accuracy: 0.9863 - val_loss: 1.9954 - val_accuracy: 0.3951
# Epoch 70/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.0930 - accuracy: 0.9882 - val_loss: 1.8966 - val_accuracy: 0.3781
# Epoch 71/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1094 - accuracy: 0.9870 - val_loss: 1.9890 - val_accuracy: 0.3478
# Epoch 72/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1152 - accuracy: 0.9849 - val_loss: 1.9910 - val_accuracy: 0.3459
# Epoch 73/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.0985 - accuracy: 0.9857 - val_loss: 2.0115 - val_accuracy: 0.3629
# Epoch 74/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1099 - accuracy: 0.9859 - val_loss: 1.8839 - val_accuracy: 0.3762
# Epoch 75/80
# 75/75 [==============================] - 8s 111ms/step - loss: 0.0887 - accuracy: 0.9870 - val_loss: 1.9192 - val_accuracy: 0.3573
# Epoch 76/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1200 - accuracy: 0.9844 - val_loss: 1.8527 - val_accuracy: 0.3686
# Epoch 77/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1129 - accuracy: 0.9846 - val_loss: 1.9769 - val_accuracy: 0.3516
# Epoch 78/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1478 - accuracy: 0.9800 - val_loss: 1.9501 - val_accuracy: 0.3743
# Epoch 79/80
# 75/75 [==============================] - 8s 111ms/step - loss: 0.1236 - accuracy: 0.9849 - val_loss: 1.8644 - val_accuracy: 0.3573
# Epoch 80/80
# 75/75 [==============================] - 8s 110ms/step - loss: 0.1067 - accuracy: 0.9838 - val_loss: 1.8210 - val_accuracy: 0.3686
# 149/149 [==============================] - 4s 27ms/step - loss: 0.6400 - accuracy: 0.8015
#
# Performance of best model:
# > Train accuracy: 0.8014721274375916
# 17/17 [==============================] - 0s 27ms/step - loss: 1.1576 - accuracy: 0.4064
# > Val accuracy: 0.4064272344112396
# 97/97 [==============================] - 3s 27ms/step - loss: 1.1473 - accuracy: 0.4542
# > Test accuracy: 0.45419228076934814
# 97/97 [==============================] - 4s 25ms/step
# Confusion Matrix:
# [[  35   44   46]
#  [  38   72   39]
#  [ 548  971 1296]]

# %%
# Saving the model
vit_classifier.save("vit_model")

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# 1. Predict probabilities and take argmax to get the class predictions
y_pred = vit_classifier.predict(x_test)  # Predict
y_pred_classes = y_pred.argmax(axis=1)   # Convert probabilities to class labels
y_true_classes = y_test.argmax(axis=1)   # True class labels

# 2. Define class labels
class_labels = ['Stay', 'Buy', 'Sell']  # Custom labels for your classes

# 3. Generate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# 4. Display the confusion matrix with labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Buy, Sell, Stay")
plt.show()

# 5. Print detailed classification report
print("Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_labels))
# Out:
# 97/97 [==============================] - 3s 26ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         Stay       0.06      0.28      0.09       125
#          Buy       0.07      0.48      0.12       149
#         Sell       0.94      0.46      0.62      2815
#
#     accuracy                           0.45      3089
#    macro avg       0.35      0.41      0.28      3089
# weighted avg       0.86      0.45      0.57      3089

# %% [markdown]
# # ResNet50

# %%
x_train_resnet = tf.keras.applications.resnet.preprocess_input(x_train)
x_val_resnet = tf.keras.applications.resnet.preprocess_input(x_val)
x_test_resnet = tf.keras.applications.resnet.preprocess_input(x_test)

# %%
# # Delete the non-resnet x data to save memory
# del x_train
# del x_val
# del x_test

# %%
resnet_classifier = tf.keras.models.Sequential([
  tf.keras.applications.ResNet50(include_top=False, input_shape=(224,224,3)),
  layers.GlobalAveragePooling2D(name='avg_pool'),
  layers.Dense(3, name='logits')
])

# %%
history = run_experiment(resnet_classifier, x_train_resnet, y_train, x_val_resnet, y_val, x_test_resnet, y_test, 'ResNet50')
resnet_classifier.save("ResNet50")
# Out:
# Epoch 1/80
# 75/75 [==============================] - 36s 383ms/step - loss: 3.3012 - accuracy: 0.3472 - val_loss: 2.8206 - val_accuracy: 0.3743
# Epoch 2/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.9296 - accuracy: 0.3563 - val_loss: 61.0133 - val_accuracy: 0.3516
# Epoch 3/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.9044 - accuracy: 0.3443 - val_loss: 1.3798 - val_accuracy: 0.3554
# Epoch 4/80
# 75/75 [==============================] - 27s 355ms/step - loss: 2.8780 - accuracy: 0.3525 - val_loss: 1.1477 - val_accuracy: 0.3819
# Epoch 5/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.8627 - accuracy: 0.3617 - val_loss: 1.1175 - val_accuracy: 0.3346
# Epoch 6/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.8121 - accuracy: 0.3968 - val_loss: 1.1452 - val_accuracy: 0.3251
# Epoch 7/80
# 75/75 [==============================] - 25s 334ms/step - loss: 2.7480 - accuracy: 0.4332 - val_loss: 1.1008 - val_accuracy: 0.3611
# Epoch 8/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.7139 - accuracy: 0.4524 - val_loss: 1.2513 - val_accuracy: 0.2968
# Epoch 9/80
# 75/75 [==============================] - 25s 332ms/step - loss: 2.6196 - accuracy: 0.5033 - val_loss: 1.1400 - val_accuracy: 0.3535
# Epoch 10/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.4740 - accuracy: 0.5493 - val_loss: 1.8723 - val_accuracy: 0.3535
# Epoch 11/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.3077 - accuracy: 0.5912 - val_loss: 2.0819 - val_accuracy: 0.3195
# Epoch 12/80
# 75/75 [==============================] - 25s 333ms/step - loss: 2.0505 - accuracy: 0.6589 - val_loss: 1.7835 - val_accuracy: 0.3270
# Epoch 13/80
# 75/75 [==============================] - 25s 333ms/step - loss: 1.7805 - accuracy: 0.7052 - val_loss: 1.4236 - val_accuracy: 0.3478
# 75/75 [==============================] - 25s 333ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 2.8221 - val_accuracy: 0.3989
# 149/149 [==============================] - 10s 60ms/step - loss: 0.0191 - accuracy: 0.9964
#
# Performance of best model:
# > Train accuracy: 0.9964247941970825
# 17/17 [==============================] - 1s 59ms/step - loss: 3.2326 - accuracy: 0.4291
# > Val accuracy: 0.4291115403175354
# 97/97 [==============================] - 6s 60ms/step - loss: 4.9987 - accuracy: 0.2664
# > Test accuracy: 0.26642927527427673
# 23/97 [======>.......................] - ETA: 4s

# %% [markdown]
# # Performing Undersampling

# %%
# Function to perform undersampling
def undersample_data(x, y, target_class, target_count):
    indices = np.where(y.argmax(axis=1) == target_class)[0]
    np.random.shuffle(indices)
    selected_indices = indices[:target_count]
    return x[selected_indices], y[selected_indices]

# Determine the target count for all classes (equal to the minority class count)
target_count = min(np.sum(y_train.argmax(axis=1) == i) for i in range(3))

# Undersample the SELL class (class 2)
x_train_sell, y_train_sell = undersample_data(x_train, y_train, target_class=2, target_count=target_count)

# Keep all samples of the BUY and STAY classes
x_train_buy = x_train[y_train.argmax(axis=1) == 1]
y_train_buy = y_train[y_train.argmax(axis=1) == 1]
x_train_stay = x_train[y_train.argmax(axis=1) == 0]
y_train_stay = y_train[y_train.argmax(axis=1) == 0]

# Combine the undersampled and original data to form the balanced dataset
x_train_balanced = np.concatenate([x_train_buy, x_train_sell, x_train_stay], axis=0)
y_train_balanced = np.concatenate([y_train_buy, y_train_sell, y_train_stay], axis=0)

# Shuffle the balanced training dataset
indices = np.arange(x_train_balanced.shape[0])
np.random.shuffle(indices)
x_train_balanced = x_train_balanced[indices]
y_train_balanced = y_train_balanced[indices]

# %%
# Analyze the balanced class distribution
print("Balanced Class Distribution:")
print(pd.DataFrame({'Class': [0, 1, 2], 'Count': np.sum(y_train_balanced, axis=0)}))
# Out:
# Balanced Class Distribution:
#    Class   Count
# 0      0  1510.0
# 1      1  1669.0
# 2      2  1510.0

# %% [markdown]
# # ViT

# %%
vit_classifier = create_vit_classifier((image_size, image_size, 3), data_preprocessing)
history_vit = run_experiment(
    vit_classifier,
    x_train_balanced,
    y_train_balanced,
    x_val,
    y_val,
    x_test,
    y_test,
    "ViT_224_Balanced",
)
# Out:
# Epoch 1/80
# 74/74 [==============================] - 21s 148ms/step - loss: 6.5715 - accuracy: 0.3510 - val_loss: 1.1111 - val_accuracy: 0.2968
# Epoch 2/80
# 74/74 [==============================] - 10s 136ms/step - loss: 3.0849 - accuracy: 0.3427 - val_loss: 1.0946 - val_accuracy: 0.3686
# Epoch 3/80
# 74/74 [==============================] - 8s 111ms/step - loss: 2.9649 - accuracy: 0.3527 - val_loss: 1.0990 - val_accuracy: 0.3554
# Epoch 4/80
# 74/74 [==============================] - 8s 111ms/step - loss: 2.9360 - accuracy: 0.3555 - val_loss: 1.0924 - val_accuracy: 0.3459
# Epoch 5/80
# 74/74 [==============================] - 8s 112ms/step - loss: 2.9143 - accuracy: 0.3630 - val_loss: 1.0926 - val_accuracy: 0.3516
# Epoch 6/80
# 74/74 [==============================] - 8s 111ms/step - loss: 2.8813 - accuracy: 0.3728 - val_loss: 1.0945 - val_accuracy: 0.3667
# Epoch 7/80
# 74/74 [==============================] - 8s 111ms/step - loss: 2.9040 - accuracy: 0.3602 - val_loss: 1.0875 - val_accuracy: 0.3686
# Confusion Matrix:
# [[  25   49   51]
#  [  25   59   65]
#  [ 432  903 1480]]

# %%
vit_classifier.save("vit_model_balanced")

# %% [markdown]
# # Resnet50

# %%
# Prepare ResNet50 inputs
x_train_resnet_balanced = tf.keras.applications.resnet.preprocess_input(x_train_balanced)
x_val_resnet = tf.keras.applications.resnet.preprocess_input(x_val)
x_test_resnet = tf.keras.applications.resnet.preprocess_input(x_test)

# Train the ResNet50 model
resnet_classifier = tf.keras.models.Sequential([
    tf.keras.applications.ResNet50(include_top=False, input_shape=(224, 224, 3)),
    layers.GlobalAveragePooling2D(name="avg_pool"),
    layers.Dense(3, name="logits"),
])
history_resnet = run_experiment(
    resnet_classifier,
    x_train_resnet_balanced,
    y_train_balanced,
    x_val_resnet,
    y_val,
    x_test_resnet,
    y_test,
    "ResNet50_Balanced",
)
# Out:
# Epoch 1/65
# 74/74 [==============================] - 37s 406ms/step - loss: 3.3973 - accuracy: 0.3606 - val_loss: 18.9016 - val_accuracy: 0.3516
# Epoch 2/65
# 74/74 [==============================] - 26s 351ms/step - loss: 2.9273 - accuracy: 0.3956 - val_loss: 1.2145 - val_accuracy: 0.3535
# Epoch 3/65
# 74/74 [==============================] - 25s 332ms/step - loss: 2.8047 - accuracy: 0.4314 - val_loss: 1.6948 - val_accuracy: 0.3459
# Epoch 4/65
# 74/74 [==============================] - 26s 351ms/step - loss: 2.7395 - accuracy: 0.4643 - val_loss: 1.2512 - val_accuracy: 0.3951
# Epoch 5/65
# 74/74 [==============================] - 25s 333ms/step - loss: 2.5687 - accuracy: 0.5236 - val_loss: 1.5615 - val_accuracy: 0.3724
# Epoch 6/65
# 74/74 [==============================] - 26s 351ms/step - loss: 2.3488 - accuracy: 0.5750 - val_loss: 1.3835 - val_accuracy: 0.3970
# Epoch 7/65
# 74/74 [==============================] - 25s 332ms/step - loss: 2.1068 - accuracy: 0.6421 - val_loss: 1.6096 - val_accuracy: 0.3724
# Epoch 8/65
# 74/74 [==============================] - 25s 332ms/step - loss: 1.8186 - accuracy: 0.6946 - val_loss: 2.1269 - val_accuracy: 0.3592
# Epoch 9/65
# 74/74 [==============================] - 25s 332ms/step - loss: 1.3925 - accuracy: 0.7756 - val_loss: 1.9891 - val_accuracy: 0.3837
# Epoch 10/65
# 74/74 [==============================] - 25s 333ms/step - loss: 1.1250 - accuracy: 0.8275 - val_loss: 1.7784 - val_accuracy: 0.3932
# Epoch 11/65
# 74/74 [==============================] - 26s 352ms/step - loss: 0.8534 - accuracy: 0.8727 - val_loss: 2.0118 - val_accuracy: 0.3989
# Epoch 12/65
# 74/74 [==============================] - 25s 333ms/step - loss: 0.7554 - accuracy: 0.8874 - val_loss: 2.7749 - val_accuracy: 0.3989
# Epoch 13/65
# 74/74 [==============================] - 26s 352ms/step - loss: 0.5136 - accuracy: 0.9254 - val_loss: 2.1015 - val_accuracy: 0.4234
# Epoch 14/65
# 74/74 [==============================] - 25s 333ms/step - loss: 0.3716 - accuracy: 0.9516 - val_loss: 4.0340 - val_accuracy: 0.3837
# Epoch 15/65
# 74/74 [==============================] - 25s 333ms/step - loss: 0
65
# 74/74 [==============================] - 25s 333ms/step - loss: 0.1225 - accuracy: 0.9851 - val_loss: 3.3784 - val_accuracy: 0.3856
# Epoch 65/65
# 74/74 [==============================] - 25s 333ms/step - loss: 0.2466 - accuracy: 0.9682 - val_loss: 2.9802 - val_accuracy: 0.4102

# %%
resnet_classifier.save("ResNet50_balanced")

# %% [markdown]
# # Piplining

# %%
# import pandas as pd
# import numpy as np
# import tensorflow as tf
# from tensorflow import keras
# import glob
# from PIL import Image
# import mplfinance as fplt
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import LabelEncoder

# %%
# model = tf.keras.models.load_model('/kaggle/working/vit_model')

# %% [markdown]
# ## Load data

# %%
# new_data = pd.read_csv('/kaggle/input/new-data-m1/data')

# %%
# import os
# import pandas as pd
# import mplfinance as fplt

# import pandas as pd

# def preprocess_new_data(df):
#     # Check and rename columns to match required format
#     required_columns = ['time', 'bid_o', 'bid_h', 'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c']
#     if not all(col in df.columns for col in required_columns):
#         raise KeyError(f"Missing required columns: {set(required_columns) - set(df.columns)}")
    
#     # Create 'Date' column from 'time' (ensure datetime format)
#     df['Date'] = pd.to_datetime(df['time'])
    
#     # Create OHLC columns (average of bid and ask prices)
#     df['Open'] = (df['bid_o'] + df['ask_o']) / 2
#     df['High'] = (df['bid_h'] + df['ask_h']) / 2
#     df['Low'] = (df['bid_l'] + df['ask_l']) / 2
#     df['Close'] = (df['bid_c'] + df['ask_c']) / 2

#     # Select only the required columns for candlestick plotting
#     df = df[['Date', 'Open', 'High', 'Low', 'Close']]

#     # Set 'Date' as the index
#     df.set_index('Date', inplace=True)

#     return df



# def generate_candlestick_images(df, save_image_path):
#     # Ensure the save path exists
#     if not os.path.exists(save_image_path):
#         os.makedirs(save_image_path)
    
#     for idx in range(len(df)):
#         # Select the last 50 rows (candles)
#         candle_data = df.iloc[max(0, idx-49):idx+1]
        
#         # Generate and save the candlestick chart
#         save_file = os.path.join(save_image_path, f"candle_{idx}.png")
#         fplt.plot(
#             candle_data,
#             type='candle',
#             style='yahoo',
#             savefig=dict(fname=save_file, dpi=100)
#         )

# %%
# import cv2
# import numpy as np

# def predict_actions(image_folder):
#     predictions = []
#     image_files = sorted(os.listdir(image_folder))  # Sort by file name for consistency
    
#     for image_file in image_files:
#         image_path = os.path.join(image_folder, image_file)
        
#         # Load the image and preprocess it for the model
#         image = cv2.imread(image_path)
#         image = cv2.resize(image, (224, 224))  # Assuming model expects 224x224 input
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
#         image = image / 255.0  # Normalize pixel values
#         image = np.expand_dims(image, axis=0)  # Add batch dimension
        
#         # Predict the action
#         prediction = model.predict(image)
#         action = np.argmax(prediction)  # Get the index of the highest probability
        
#         # Map the index to the action
#         action_map = {0: "stay", 1: "buy", 2: "sell"}
#         predictions.append(action_map[action])
    
#     return predictions

# %%
# # Preprocess the data
# preprocessed_data = preprocess_new_data(new_data)

# # Generate candlestick images
# generate_candlestick_images(preprocessed_data, save_image_path="/kaggle/working/images")

# %%
# predictions = predict_actions("/kaggle/working/images")
# print("Predicted Actions:", predictions)
